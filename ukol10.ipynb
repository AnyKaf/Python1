# %% [markdown]
# # Domácí úkol 10
# ##

# %% [markdown]
# ## Zadání 1

# %%
import pandas
zam_praha = pandas.read_csv("zam_praha.csv")
zam_plzen = pandas.read_csv("zam_plzeň.csv")
zam_liberec = pandas.read_csv("zam_liberec.csv")

# %%
zam_praha["mesto"] = "Praha"
zam_plzen["mesto"] = "Plzeň"
zam_liberec["mesto"] = "Liberec"

# %%
zamestnanci = pandas.concat([zam_praha, zam_plzen, zam_liberec], ignore_index = True)
zamestnanci
# Out:
#           jmeno    prijimeni   telefonni_cislo  cislo_zamestnance    mesto
# 0         Brian         Hall  +421 949 656 098                 30    Praha
# 1         Marta     Kolářová       730 456 163                 32    Praha
# 2          John      Moravec       725 092 179                 33    Praha
# 3      Dominika      Kopecká       722 747 626                 34    Praha
# 4        Marcel        Hájek  +421 902 928 669                 35    Praha
# 5        Milada    Hernandez       773 373 704                 38    Praha
# 6     Catherine       Bender       604 068 460                 40    Praha
# 7          Olga      Němcová  +421 914 172 243                 41    Praha
# 8       Jeffrey      Šťastný       607 628 821                 44    Praha
# 9        Kamila       Říhová  +421 948 396 069                 47    Praha
# 10      Jaromír       Miller  +421 912 615 902                 49    Praha
# ...

# %%
platy = pandas.read_csv("platy_2021_02.csv")

# %%
new_tab = pandas.merge( zamestnanci, platy, on = "cislo_zamestnance", how = "left")
new_tab
# Out:
#           jmeno    prijimeni   telefonni_cislo  cislo_zamestnance    mesto  \
# 0         Brian         Hall  +421 949 656 098                 30    Praha
# 1         Marta     Kolářová       730 456 163                 32    Praha
# 2          John      Moravec       725 092 179                 33    Praha
# 3      Dominika      Kopecká       722 747 626                 34    Praha
# 4        Marcel        Hájek  +421 902 928 669                 35    Praha
# 5        Milada    Hernandez       773 373 704                 38    Praha
# 6     Catherine       Bender       604 068 460                 40    Praha
# 7          Olga      Němcová  +421 914 172 243                 41    Praha
# 8       Jeffrey      Šťastný       607 628 821                 44    Praha
# 9        Kamila       Říhová  +421 948 396 069                 47    Praha
# 10      Jaromír       Miller  +421 912 615 902                 49    Praha
# ...

# %%
new_tab.groupby("mesto")["plat"].mean()
# Out:
# mesto
# Liberec    43775.000000
# Plzeň      44792.857143
# Praha      43295.238095
# Name: plat, dtype: float64

# %% [markdown]
# ## Zadání 2

# %%
vykazy = pandas.read_csv("vykazy.csv")
vykazy
# Out:
#           date  hours project  emloyee_id
# 0   2021-02-01    2.5     F30          13
# 1   2021-02-01    3.4     W05          70
# 2   2021-02-01    2.1     JL9          72
# 3   2021-02-01    5.2     F30           3
# 4   2021-02-01    2.4     TE1          54
# 5   2021-02-01    4.1     TE1          83
# 6   2021-02-01    5.4     W05          92
# 7   2021-02-01    2.2     YLI          34
# 8   2021-02-01    2.7     YLI          84
# 9   2021-02-01    4.4     W05          30
# 10  2021-02-02    5.6     F30          53
# 11  2021-02-02    2.6     W05          47
# 12  2021-02-02    2.4     YLI          44
# 13  2021-02-02    3.1     YLI          40
# 14  2021-02-02    5.3     YLI          10
# 15  2021-02-02    3.6     YLI          53
# 16  2021-02-02    5.6     F30          56
# 17  2021-02-03    4.0     W05          53
# 18  2021-02-03    4.6     TE1          86
# 19  2021-02-03    2.6     F30          18
# 20  2021-02-03    2.8     TE1          47
# ...

# %%
hodiny_na_projektech = vykazy.groupby("project")["hours"].sum()
hodiny_na_projektech
# Out:
# project
# F30    21.5
# JL9     2.1
# TE1    16.0
# W05    30.5
# YLI    31.0
# Name: hours, dtype: float64

# %% [markdown]
# ## Bonus 1

# %%
nepracuji = new_tab[new_tab["plat"].isna()]
nepracuji["jmeno"].count()
# Out:
# 13

# %%
nepracuji.to_csv("nepracuji.csv", index=False)

# %% [markdown]
# ## Bonus 2

# %%
vykazy.rename(columns = {"emloyee_id" : "cislo_zamestnance"}, inplace = True)
vykazy
# Out:
#           date  hours project  cislo_zamestnance
# 0   2021-02-01    2.5     F30                 13
# 1   2021-02-01    3.4     W05                 70
# 2   2021-02-01    2.1     JL9                 72
# 3   2021-02-01    5.2     F30                  3
# 4   2021-02-01    2.4     TE1                 54
# 5   2021-02-01    4.1     TE1                 83
# 6   2021-02-01    5.4     W05                 92
# 7   2021-02-01    2.2     YLI                 34
# 8   2021-02-01    2.7     YLI                 84
# 9   2021-02-01    4.4     W05                 30
# 10  2021-02-02    5.6     F30                 53
# 11  2021-02-02    2.6     W05                 47
# 12  2021-02-02    2.4     YLI                 44
# 13  2021-02-02    3.1     YLI                 40
# 14  2021-02-02    5.3     YLI                 10
# 15  2021-02-02    3.6     YLI                 53
# 16  2021-02-02    5.6     F30                 56
# 17  2021-02-03    4.0     W05                 53
# ...

# %%
zamestnanci_projekty = pandas.merge(new_tab, vykazy, on = "cislo_zamestnance",)
zamestnanci_projekty

#zaroven se tabulka "vycisti" od zamestnancu kteri nepracovali na projektech --> pro cviceni nam staci zaradit pocet hodin do kancelare
# Out:
#         jmeno    prijimeni   telefonni_cislo  cislo_zamestnance    mesto  \
# 0       Brian         Hall  +421 949 656 098                 30    Praha
# 1    Dominika      Kopecká       722 747 626                 34    Praha
# 2    Dominika      Kopecká       722 747 626                 34    Praha
# 3   Catherine       Bender       604 068 460                 40    Praha
# 4   Catherine       Bender       604 068 460                 40    Praha
# 5     Jeffrey      Šťastný       607 628 821                 44    Praha
# 6      Kamila       Říhová  +421 948 396 069                 47    Praha
# 7      Kamila       Říhová  +421 948 396 069                 47    Praha
# 8    Karolína        Short       721 589 083                 53    Praha
# 9    Karolína        Short       721 589 083                 53    Praha
# 10   Karolína        Short       721 589 083                 53    Praha
# 11   Michelle      Vlčková  +421 41 720 7806                 54    Praha
# ...

# %%
projekty_praha = (zamestnanci_projekty[zamestnanci_projekty["mesto"] == "Praha"]).groupby("project")["hours"].sum()
print(projekty_praha)

projekty_plzen =(zamestnanci_projekty[zamestnanci_projekty["mesto"] == "Plzeň"]).groupby("project")["hours"].sum()
print(projekty_plzen)

projekty_liberec = (zamestnanci_projekty[zamestnanci_projekty["mesto"] == "Liberec"]).groupby("project")["hours"].sum()
print(projekty_liberec)
# Out:
# project
# F30    11.2
# JL9     2.1
# TE1     5.2
# W05    25.1
# YLI    13.9
# Name: hours, dtype: float64
# project
# F30    10.3
# YLI     5.3
# Name: hours, dtype: float64
# project
# TE1    10.8
# W05     5.4
# YLI    11.8
# Name: hours, dtype: float64
