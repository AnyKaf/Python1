# %% [markdown]
# # Úkol 11 :)

# %%
import pandas
platy = pandas.read_csv("platy_2021_02.csv")
platy
# Out:
#     cislo_zamestnance     plat
# 0                   3  54900.0
# 1                   6  54800.0
# 2                   7  36400.0
# 3                   8  47900.0
# 4                  16  34200.0
# 5                  18  35400.0
# 6                  21  54200.0
# 7                  22  34400.0
# 8                  23  39000.0
# 9                  24  44200.0
# 10                 26  59600.0
# 11                 27  45100.0
# 12                 28  38100.0
# 13                 29  48900.0
# 14                 30  33500.0
# 15                 32  53000.0
# 16                 33  38400.0
# 17                 34  36800.0
# 18                 38  32600.0
# 19                 40  32800.0
# 20                 41  49300.0
# 21                 44  52000.0
# 22                 47  40700.0
# 23                 49  58400.0
# 24                 51  37100.0
# 25                 56  39300.0
# 26                 57  36800.0
# 27                 63  31400.0
# 28                 64  36900.0
# ...

# %%
platy["plat"].plot(kind='hist', bins=6, grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Nepovinný bonus 1

# %%
teploty = pandas.read_csv("temperature.csv")

vybrane_teploty = teploty[teploty["City"].isin(["Miami Beach", "Helsinki", "Tokyo"])]
vybrane_teploty = vybrane_teploty.set_index("City")
vybrane_teploty
# Out:
#                     Region Country  Day  AvgTemperature
# City
# Tokyo                 Asia   Japan    1            59.1
# Tokyo                 Asia   Japan    2            62.3
# Tokyo                 Asia   Japan    3            64.1
# Tokyo                 Asia   Japan    4            59.6
# Tokyo                 Asia   Japan    5            57.0
# ...                    ...     ...  ...             ...
# Miami Beach  North America      US   26            73.5
# Miami Beach  North America      US   27            73.1
# Miami Beach  North America      US   28            77.5
# Miami Beach  North America      US   29            77.7
# Miami Beach  North America      US   30            78.0
#
# [90 rows x 4 columns]

# %%
vybrane_teploty.boxplot(by = "City")
# Out:
# array([<Axes: title={'center': 'AvgTemperature'}, xlabel='[City]'>,
#        <Axes: title={'center': 'Day'}, xlabel='[City]'>], dtype=object)

# %% [markdown]
# jen nevím proč mám ty grafíky dva :(
